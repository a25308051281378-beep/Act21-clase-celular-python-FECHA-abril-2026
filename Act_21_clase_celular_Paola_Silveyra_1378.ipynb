# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051281378-beep/Act21-clase-celular-python-FECHA-abril-2026/blob/main/Act_21_clase_celular_Paola_Silveyra_1378.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Paola Silveyra NL = 50 Fecha 22/04/26
# ## Clase celular
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051281378-beep/Act21-clase-celular-python-FECHA-abril-2026/refs/heads/main/InfoClaseCelular.png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "iPhone 15", 1000)
# llamadas a las funciones para cada objeto celular 1 y celular 2
print("Celular1:")
cel1.mostrar_info()
cel1.encender()

print("Celular2:")
cel2.mostrar_info()
cel2.encender()

print("Programa terminado")
print("Creador de software por Paola Silveyra NL = 50")
# Out:
# Celular1:
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
# Celular2:
# Celular: Apple iPhone 15, Precio: $1000
# El iPhone 15 se ha encendido.
# Programa terminado
# Creador de software por Paola Silveyra NL = 50

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051281378-beep/Act21-clase-celular-python-FECHA-abril-2026/refs/heads/main/LogicaFuncionamiento.png)
